# %%
import pandas as pd
from pandas import option_context
import numpy as np
import re
import string

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import MWETokenizer
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer 

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 

from collections import Counter

from textblob import TextBlob

# %%
df = pd.read_csv('04-data/preprocessed_app_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22032 entries, 0 to 22031
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     22032 non-null  object
#  1   description               22032 non-null  object
#  2   summary                   22031 non-null  object
#  3   installs                  22032 non-null  object
#  4   minInstalls               22032 non-null  float64
#  5   score                     22032 non-null  float64
#  6   ratings                   22032 non-null  float64
#  7   reviews                   22032 non-null  float64
#  8   histogram                 22032 non-null  object
#  9   price                     22032 non-null  float64
#  10  free                      22032 non-null  int64
#  11  currency                  22032 non-null  object
#  12  sale                      22032 non-null  bool
#  13  offersIAP                 22032 non-null  bool
#  14  inAppProductPrice         10303 non-null  object
#  15  size                      22032 non-null  object
#  16  androidVersion            22005 non-null  object
#  17  androidVersionText        22005 non-null  object
#  18  developer                 22032 non-null  object
#  19  developerId               22032 non-null  object
#  20  privacyPolicy             21228 non-null  object
#  21  developerInternalID       22032 non-null  float64
#  22  genre                     22032 non-null  object
#  23  genreId                   22032 non-null  object
#  24  icon                      22032 non-null  object
#  25  headerImage               22029 non-null  object
#  26  screenshots               22032 non-null  object
#  27  video                     7348 non-null   object
#  28  videoImage                7348 non-null   object
#  29  contentRating             22032 non-null  object
#  30  contentRatingDescription  4785 non-null   object
#  31  adSupported               17867 non-null  object
#  32  containsAds               22032 non-null  int64
#  33  released                  22032 non-null  object
#  34  updated                   22032 non-null  object
#  35  version                   22029 non-null  object
#  36  recentChanges             17632 non-null  object
#  37  comments                  22032 non-null  object
#  38  editorsChoice             22032 non-null  int64
#  39  appId                     22032 non-null  object
#  40  url                       22032 non-null  object
#  41  year                      22032 non-null  int64
#  42  updated_year              22032 non-null  int64
#  43  description_clean         22031 non-null  object
#  44  hist_clean                22032 non-null  object
#  45  star_1                    22032 non-null  int64
#  46  star_2                    22032 non-null  int64
#  47  star_3                    22032 non-null  int64
#  48  star_4                    22032 non-null  int64
#  49  star_5                    22032 non-null  int64
#  50  top_developer             22032 non-null  int64
#  51  current_date              22032 non-null  object
#  52  days                      22032 non-null  int64
#  53  installs_day              22032 non-null  float64
#  54  updated_days              22032 non-null  int64
#  55  has_video                 22032 non-null  int64
# dtypes: bool(2), float64(7), int64(14), object(33)
# memory usage: 9.1+ MB

# %%
df.title.nunique()
# Out:
# 22032

# %%
df[df['title'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [title, description, summary, installs, minInstalls, score, ratings, reviews, histogram, price, free, currency, sale, offersIAP, inAppProductPrice, size, androidVersion, androidVersionText, developer, developerId, privacyPolicy, developerInternalID, genre, genreId, icon, headerImage, screenshots, video, videoImage, contentRating, contentRatingDescription, adSupported, containsAds, released, updated, version, recentChanges, comments, editorsChoice, appId, url, year, updated_year, description_clean, hist_clean, star_1, star_2, star_3, star_4, star_5, top_developer, current_date, days, installs_day, updated_days, has_video]
# Index: []
#
# [0 rows x 56 columns]

# %%
df_analysis = df[['title','score','comments']].copy()
df_analysis.reset_index(drop=True,inplace=True)

# %%
df_analysis = pd.DataFrame(df_analysis.comments.str.split(",").tolist(), index=df_analysis.title).stack()
df_analysis = df_analysis.reset_index([0, 'title'])
df_analysis.columns = ['title', 'comments']

# %%
df_analysis
# Out:
#                                  title  \
# 0        World War 2: Offline Strategy
# 1        World War 2: Offline Strategy
# 2        World War 2: Offline Strategy
# 3        World War 2: Offline Strategy
# 4        World War 2: Offline Strategy
# ...                                ...
# 1474258             Tarot Card Reading
# 1474259             Tarot Card Reading
# 1474260             Tarot Card Reading
# 1474261             Tarot Card Reading
# 1474262             Tarot Card Reading
#
#                                                   comments
# 0                                 ["I just started playing
# 1         I'm on the 3rd level and it's already so hard...
# 2         games are fun when they are easy to play but ...
# 3         plus there are way too many ads on this game....
# 4                   "Fun game to play with decent graphics
# ...                                                    ...
# 1474258
# 1474259                    we all are destined to be here
# 1474260   there and maybe for the unsure anywhere for a...
# 1474261   'This app is very awesome and amazing and eve...
# 1474262   'Not enough content to motivate me to deal wi...
#
# [1474263 rows x 2 columns]

# %%
def clean_text(text):
    '''Make text lowercase, remove punctuation, remove links and mentions'''
    text = text.lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub('[0-9\n]',' ',text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub("\s\s+", " ", text)
    
    return text

df_analysis['comments'] = df_analysis.comments.map(clean_text)

# %%
sid_obj = SentimentIntensityAnalyzer()
sentiment = []
for comment in df_analysis.comments:
    sentiment.append(sid_obj.polarity_scores(comment))

# %%
sentiment_df = pd.DataFrame(sentiment)
sentiment_df
# Out:
#            neg    neu    pos  compound
# 0        0.000  0.625  0.375    0.2023
# 1        0.206  0.794  0.000   -0.4409
# 2        0.071  0.647  0.281    0.8555
# 3        0.119  0.766  0.115   -0.0258
# 4        0.000  0.467  0.533    0.6908
# ...        ...    ...    ...       ...
# 1474258  0.000  0.000  0.000    0.0000
# 1474259  0.000  1.000  0.000    0.0000
# 1474260  0.031  0.933  0.036    0.0644
# 1474261  0.000  0.510  0.490    0.9109
# 1474262  0.000  0.809  0.191    0.3818
#
# [1474263 rows x 4 columns]

# %%
df_merged = pd.concat([df_analysis,sentiment_df],axis=1)

# %%
df_merged.shape
# Out:
# (1474263, 6)

# %%
new = pd.DataFrame(df_merged.groupby('title')['compound'].mean())

# %%
new
# Out:
#                                                     compound
# title
# "Memory Game for kids" - Memory Game                0.428942
# #1 Vocab App: Hindu Editorial, Grammar, Dictionary  0.475844
# (FPL) Fantasy Football Manager for Premier League   0.269035
# (FREE) DEER GO THEME SET                            0.310362
# (FREE) Firefly 2 In 1 Theme                         0.216624
# ...                                                      ...
# zlap.io                                            -0.224836
# zombie comando shooting:offline fps military-games  0.307505
# zumba classic deluxe                                0.350258
# zumba deluxe 2020                                   0.337665
# ✨Impossible Draw👆: Color helix puzzle maze          0.236921
#
# [22032 rows x 1 columns]

# %%
test = df_merged[['title','compound']]

# %%
test
# Out:
#                                  title  compound
# 0        World War 2: Offline Strategy    0.2023
# 1        World War 2: Offline Strategy   -0.4409
# 2        World War 2: Offline Strategy    0.8555
# 3        World War 2: Offline Strategy   -0.0258
# 4        World War 2: Offline Strategy    0.6908
# ...                                ...       ...
# 1474258             Tarot Card Reading    0.0000
# 1474259             Tarot Card Reading    0.0000
# 1474260             Tarot Card Reading    0.0644
# 1474261             Tarot Card Reading    0.9109
# 1474262             Tarot Card Reading    0.3818
#
# [1474263 rows x 2 columns]

# %%
test['compound'].describe()
# Out:
# count    1.474263e+06
# mean     2.475378e-01
# std      4.757153e-01
# min     -1.000000e+00
# 25%      0.000000e+00
# 50%      2.931000e-01
# 75%      6.369000e-01
# max      1.000000e+00
# Name: compound, dtype: float64

# %%
df_merged
# Out:
#                                  title  \
# 0        World War 2: Offline Strategy
# 1        World War 2: Offline Strategy
# 2        World War 2: Offline Strategy
# 3        World War 2: Offline Strategy
# 4        World War 2: Offline Strategy
# ...                                ...
# 1474258             Tarot Card Reading
# 1474259             Tarot Card Reading
# 1474260             Tarot Card Reading
# 1474261             Tarot Card Reading
# 1474262             Tarot Card Reading
#
#                                                   comments    neg    neu  \
# 0                                   i just started playing  0.000  0.625
# 1         im on the rd level and its already so hard th...  0.206  0.794
# 2         games are fun when they are easy to play but ...  0.071  0.647
# 3         plus there are way too many ads on this game ...  0.119  0.766
# 4                    fun game to play with decent graphics  0.000  0.467
# ...                                                    ...    ...    ...
# 1474258                                                     0.000  0.000
# 1474259                    we all are destined to be here   0.000  1.000
# 1474260   there and maybe for the unsure anywhere for a...  0.031  0.933
# 1474261   this app is very awesome and amazing and ever...  0.000  0.510
# 1474262   not enough content to motivate me to deal wit...  0.000  0.809
#
#            pos  compound
# 0        0.375    0.2023
# 1        0.000   -0.4409
# 2        0.281    0.8555
# 3        0.115   -0.0258
# 4        0.533    0.6908
# ...        ...       ...
# 1474258  0.000    0.0000
# 1474259  0.000    0.0000
# 1474260  0.036    0.0644
# 1474261  0.490    0.9109
# 1474262  0.191    0.3818
#
# [1474263 rows x 6 columns]

# %%
new.to_csv('merged_sentiment.csv')
