# %%
import pandas as pd
from pandas import option_context
import numpy as np
import re
import pickle

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF, PCA
from sklearn.metrics import pairwise_distances

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import MWETokenizer
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
df = pd.read_csv('04-data/preprocessed_app_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22015 entries, 0 to 22014
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     22015 non-null  object
#  1   description               22015 non-null  object
#  2   summary                   22014 non-null  object
#  3   installs                  22015 non-null  object
#  4   minInstalls               22015 non-null  float64
#  5   score                     22015 non-null  float64
#  6   ratings                   22015 non-null  float64
#  7   reviews                   22015 non-null  float64
#  8   histogram                 22015 non-null  object
#  9   price                     22015 non-null  float64
#  10  free                      22015 non-null  int64
#  11  currency                  22015 non-null  object
#  12  sale                      22015 non-null  bool
#  13  offersIAP                 22015 non-null  bool
#  14  inAppProductPrice         10301 non-null  object
#  15  size                      22015 non-null  object
#  16  androidVersion            21988 non-null  object
#  17  androidVersionText        21988 non-null  object
#  18  developer                 22015 non-null  object
#  19  developerId               22015 non-null  object
#  20  privacyPolicy             21211 non-null  object
#  21  developerInternalID       22015 non-null  float64
#  22  genre                     22015 non-null  object
#  23  genreId                   22015 non-null  object
#  24  icon                      22015 non-null  object
#  25  headerImage               22012 non-null  object
#  26  screenshots               22015 non-null  object
#  27  video                     7342 non-null   object
#  28  videoImage                7342 non-null   object
#  29  contentRating             22015 non-null  object
#  30  contentRatingDescription  4784 non-null   object
#  31  adSupported               17861 non-null  object
#  32  containsAds               22015 non-null  int64
#  33  released                  22015 non-null  object
#  34  updated                   22015 non-null  object
#  35  version                   22012 non-null  object
#  36  recentChanges             17616 non-null  object
#  37  comments                  22015 non-null  object
#  38  editorsChoice             22015 non-null  int64
#  39  appId                     22015 non-null  object
#  40  url                       22015 non-null  object
#  41  year                      22015 non-null  int64
#  42  updated_year              22015 non-null  int64
#  43  description_clean         22012 non-null  object
#  44  hist_clean                22015 non-null  object
#  45  star_1                    22015 non-null  int64
#  46  star_2                    22015 non-null  int64
#  47  star_3                    22015 non-null  int64
#  48  star_4                    22015 non-null  int64
#  49  star_5                    22015 non-null  int64
#  50  top_developer             22015 non-null  int64
#  51  current_date              22015 non-null  object
#  52  days                      22015 non-null  int64
#  53  installs_day              22015 non-null  float64
#  54  updated_days              22015 non-null  int64
#  55  has_video                 22015 non-null  int64
# dtypes: bool(2), float64(7), int64(14), object(33)
# memory usage: 9.1+ MB

# %%
df = df[df['description_clean'].notna()]
df = df[df['score'] >= 3.8]

# %%
df_analysis = df[['title','description_clean']].copy()
df_analysis.reset_index(drop=True,inplace=True)

# %%
df_analysis
# Out:
#                                                    title  \
# 0                          World War 2: Offline Strategy
# 1       All PDF - PDF Reader, PDF Viewer & PDF Converter
# 2                         MSN Sports - Scores & Schedule
# 3                             QRbot: QR & barcode reader
# 4                                   QR & Barcode Scanner
# ...                                                  ...
# 17136  Aksara Jawa - Nulis Aksara Jawa | Ketik & Konv...
# 17137                                 Mp3 Songs Download
# 17138                                          PDF Maker
# 17139                                    DSLR Blur Photo
# 17140                                 Tarot Card Reading
#
#                                        description_clean
# 0      command  allies in 25 epic world war 2 locatio...
# 1      pdf reader for android pdfs converter free is ...
# 2      be in a league of your ownget real-time game u...
# 3      scan all kinds of qr codes and barcodes with t...
# 4      qr  barcode scannerthis qr  barcode scanner wi...
# ...                                                  ...
# 17136  aksara jawa adalah salah satu aset budaya indo...
# 17137  the application provides search stream and dow...
# 17138  main features of orangepalm s pdf maker app- s...
# 17139  this app lets you blur parts of your photo whi...
# 17140   discover your future with this free tarot car...
#
# [17141 rows x 2 columns]

# %%
stop = stopwords.words('english')
stop.extend(['free','new','get','hd','use','game','games','make','makes','play',
             'fun','features', 'need','live', 'also','using','best','us','app','apps', 'one', '2020','2021',
            'this','like','enjoy','thing','free'])

# # Extend for most common English adverbs

stop.extend(['up','so','out','just','now','how','then','more','also','here',
            'well','only','very','even','back','there','down','still','in',
            'as','to','when','never','really','most','on','why','about','over',
            'again','where','right','off','always','today','all','far','long',
            'away','yet','often','ever','however','almost','later','much',
            'once','least','ago','together','around','already','enough','both',
            'maybe','actually','probably','home','of course','perhaps','little',
            'else','sometimes','finally','less','better','early','especially',
            'either','quite','simply','nearly','soon','certainly','quickly',
            'no','recently','before','usually','thus','exactly','hard',
            'particularly','forward','ok','okay','clearly','indeed',
            'rather','that','tonight','close','suddenly','best','instead',
            'ahead','fast','alone','eventually','directly'])

# # Extend for most common irregular verbs (except pay,lose,send,buy,spend)

# stop.extend(['say','make','go','take','come','see','know','get','got','give',
#             'find','think','tell','show','leave','feel','put','bring',
#             'begin','keep','hold','stand','hear','let','mean','set',
#             'sit','lie','lead','fall','break','rise','drive','choose'])

# ## Extend for prepositions
stop.extend(['without','among'])

# %% [markdown]
# ## Stemmed

# %%
df['tokens'] = df.description_clean.apply(nltk.word_tokenize)

# %%
stemmer = PorterStemmer()

df['stemmed'] = df['tokens'].apply(lambda x: [stemmer.stem(y) for y in x])

# %%
df.tokens = df.tokens.apply(lambda x: ' '.join(x))

# %%
df.stemmed = df.stemmed.apply(lambda x: ' '.join(x))

# %%
df_analysis = df[['title','stemmed']].copy()
df_analysis.reset_index(drop=True,inplace=True)

# %%
df_analysis
# Out:
#                                                    title  \
# 0                          World War 2: Offline Strategy
# 1       All PDF - PDF Reader, PDF Viewer & PDF Converter
# 2                         MSN Sports - Scores & Schedule
# 3                             QRbot: QR & barcode reader
# 4                                   QR & Barcode Scanner
# ...                                                  ...
# 17136  Aksara Jawa - Nulis Aksara Jawa | Ketik & Konv...
# 17137                                 Mp3 Songs Download
# 17138                                          PDF Maker
# 17139                                    DSLR Blur Photo
# 17140                                 Tarot Card Reading
#
#                                                  stemmed
# 0      command alli in 25 epic world war 2 locat we h...
# 1      pdf reader for android pdf convert free is one...
# 2      be in a leagu of your ownget real-tim game upd...
# 3      scan all kind of qr code and barcod with the q...
# 4      qr barcod scannerthi qr barcod scanner will le...
# ...                                                  ...
# 17136  aksara jawa adalah salah satu aset budaya indo...
# 17137  the applic provid search stream and download a...
# 17138  main featur of orangepalm s pdf maker app- sel...
# 17139  thi app let you blur part of your photo which ...
# 17140  discov your futur with thi free tarot card rea...
#
# [17141 rows x 2 columns]

# %%
vectorizer = CountVectorizer(stop_words = stop)

doc_word = vectorizer.fit_transform(df_analysis.stemmed)
# Out:
# /Users/tawneykirkland/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['course'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
nmf_model = NMF(30)
doc_topic = nmf_model.fit_transform(doc_word)
topic_word = nmf_model.components_

# %%
words = vectorizer.get_feature_names()
t = nmf_model.components_.argsort(axis=1)[:,-1:-10:-1]
topic_words = [[words[e] for e in l] for l in t]
topic_words
# Out:
# [['card',
#   'account',
#   'busi',
#   'bank',
#   'creat',
#   'invit',
#   'money',
#   'solitair',
#   'player'],
#  ['car', 'drive', 'race', 'park', 'drift', 'stunt', 'simul', 'extrem', 'real'],
#  ['photo',
#   'frame',
#   'editor',
#   'effect',
#   'pictur',
#   'imag',
#   'background',
#   'collag',
#   'camera'],
#  ['robot',
#   'transform',
#   'fli',
#   'war',
#   'fight',
#   'battl',
#   'car',
#   'futurist',
#   'citi'],
#  ['video',
#   'maker',
#   'chat',
#   'creat',
#   'audio',
#   'player',
#   'edit',
#   'download',
#   'effect'],
#  ['keyboard',
#   'theme',
#   'emoji',
#   'type',
#   'phone',
#   'android',
#   'instal',
#   'galaxi',
#   'font'],
#  ['color',
#   'book',
#   'page',
#   'number',
#   'girl',
#   'paint',
#   'glitter',
#   'beauti',
#   'kid'],
#  ['truck',
#   'drive',
#   'transport',
#   'simul',
#   'cargo',
#   'driver',
#   'offroad',
#   'road',
#   'armi'],
#  ['shoot',
#   'gun',
#   'fp',
#   'sniper',
#   'shooter',
#   'mission',
#   'commando',
#   'terrorist',
#   'armi'],
#  ['bike',
#   'race',
#   'stunt',
#   'ramp',
#   'track',
#   'imposs',
#   'drive',
#   'moto',
#   'extrem'],
#  ['wallpap',
#   'background',
#   'screen',
#   'anim',
#   'imag',
#   'theme',
#   '3d',
#   'beauti',
#   'cute'],
#  ['phone',
#   'screen',
#   'devic',
#   'lock',
#   'android',
#   'set',
#   'launcher',
#   'support',
#   'mobil'],
#  ['bu', 'drive', 'simul', 'park', 'citi', 'coach', 'driver', '3d', 'real'],
#  ['music',
#   'player',
#   'song',
#   'sound',
#   'audio',
#   'rington',
#   'mp3',
#   'radio',
#   'listen'],
#  ['kid',
#   'learn',
#   'anim',
#   'babi',
#   'puzzl',
#   'children',
#   'educ',
#   'help',
#   'toddler'],
#  ['call',
#   'caller',
#   'number',
#   'phone',
#   'flash',
#   'record',
#   'screen',
#   'name',
#   'chat'],
#  ['slot', 'casino', 'machin', 'win', 'real', 'vega', 'spin', 'bonu', 'money'],
#  ['file',
#   'pdf',
#   'document',
#   'reader',
#   'manag',
#   'imag',
#   'scan',
#   'read',
#   'format'],
#  ['map', 'gp', 'locat', 'navig', 'rout', 'direct', 'find', 'view', 'weather'],
#  ['polic',
#   'citi',
#   'crime',
#   'gangster',
#   'chase',
#   'dog',
#   'transport',
#   'prison',
#   'simul'],
#  ['fight', 'world', 'hero', 'battl', 'power', 'citi', 'player', 'real', 'war'],
#  ['cook',
#   'food',
#   'restaur',
#   'chef',
#   'kitchen',
#   'time',
#   'manag',
#   'serv',
#   'recip'],
#  ['wifi',
#   'speed',
#   'vpn',
#   'connect',
#   'network',
#   'test',
#   'internet',
#   'data',
#   'secur'],
#  ['statu',
#   'download',
#   'whatsapp',
#   'save',
#   'saver',
#   'imag',
#   'share',
#   'stori',
#   'ani'],
#  ['birthday',
#   'name',
#   'song',
#   'cake',
#   'wish',
#   'happi',
#   'maker',
#   'creat',
#   'frame'],
#  ['thi', 'differ', 'time', 'level', 'ani', 'applic', 'veri', 'ha', 'featur'],
#  ['love',
#   'sticker',
#   'messag',
#   'stori',
#   'text',
#   'romant',
#   'day',
#   'friend',
#   'share'],
#  ['workout',
#   'train',
#   'weight',
#   'exercis',
#   'fit',
#   'day',
#   'help',
#   'bodi',
#   'loss'],
#  ['wed',
#   'girl',
#   'dress',
#   'fashion',
#   'indian',
#   'design',
#   'makeup',
#   'beauti',
#   'princess'],
#  ['word',
#   'translat',
#   'english',
#   'languag',
#   'learn',
#   'text',
#   'dictionari',
#   'voic',
#   'hindi']]

# %%
df_analysis['topic'] = doc_topic.argmax(axis=1)

# %%
df_analysis[df_analysis['topic'] == 20].sample(60)
# Out:
#                                                    title  \
# 11246                       Volleyball Championship 2014
# 16655             Iron Stickman Rope Hero Gangstar Crime
# 1513                             Brazilian Dama - Online
# 3833                                       King of Crabs
# 1165                                               1to50
# 7589                                      Soda Dungeon 2
# 7929                  Gods and Glory: War for the Throne
# 9976                                           Circuroid
# 167    Idle Space Miner - Simulator & Tycoon & Manage...
# 4125                                         Crazy Snake
# 16905                                       Dragon Drill
# 3906                                     Wizard of Bingo
# 8857                                       Mansion Blast
# 15676                       Chicken Revolution : Warrior
# 4247                       Dododex: ARK Survival Evolved
# 2092   Endless Nightmare: Epic Creepy & Scary Horror ...
# 1471                                     Micro Battles 2
# 6903                                    A Planet of Mine
# 2985                     Run Hunter Run : Monster Runner
# 6930    The Crossing Dead: Crossy Zombie Apocalypse Road
# 9097                                       Jewels Maze 2
# 8367    Heroes of Destiny: Fantasy RPG, raids every week
# 15564                                       Gravity Push
# 8961                           Dead Shell: Roguelike RPG
# 16744                   Stickman Fighting: Neon Warriors
# 6661                                        World Escape
# 14743                                        Western Man
# 8466                        MLB Tap Sports Baseball 2019
# 4225                                   Shark Tank Tycoon
# 8303                       [SF]Stellacept Online[MMORPG]
# 7685                                         Armored God
# 15788                         Stickman Killing Zombie 3D
# 7767                       AFC Solar Squad: Space Attack
# 15675                      Chicken Warrior:Zombie Hunter
# 4065                                           Toy Crush
# 179                              Draw a Stickman: EPIC 3
# 520                         Battle Empire: Rome War Game
# 13325                         Angry Lion Sim City Attack
# 6611                         Jane's Hotel 2: Family Hero
# 9333                         Flick Kick Football Legends
# 8442   Dragon Epic - Idle & Merge - Arcade shooting game
# 7181                                              REDCON
# 6749                          Adventure Escape Mysteries
# 3090    Timing Hero: Retro Fighting Action RPG Game Hero
# 8369                                       Dragon Castle
# 8144            Summoner's Greed: Endless Idle TD Heroes
# 6959                              Brain Puzzle: 99 Games
# 7925                     Abyss of Empires: The Mythology
# 7913                 Kingdom Quest Crimson Warden 3D RPG
# 3021              Double Head Shark Attack - Multiplayer
# 2574                                  Razer Cortex Games
# 9781                                  Marble Jungle 2021
# 2095                                     Stickman Racing
# 384                      Pop Stone 2 - 2021 Free Match 3
# 6699                                            Seabeard
# 9009                                    Rugby Nations 19
# 4673                   iReader - Novels, Romance Stories
# 210                                    Underworld Empire
# 14163                                         Fight King
# 1463                                          Bold Moves
#
#                                                  stemmed  topic
# 11246  volleybal championship 2014 is a full-scal wor...     20
# 16655  stickman rope hero vega crime simul iron man t...     20
# 1513   brazilian dama also known as draught or checke...     20
# 3833   intens multiplay fun battl with up to 100 real...     20
# 1165   1to50 is an easi and fun game of touch from 1 ...     20
# 7589   your favorit fizzi dungeon crawler is back the...     20
# 7929   launch yourself into an intens tactic real-tim...     20
# 9976   circuroid is an uniqu fast-pac arcad shooter w...     20
# 167    welcom to the most excit idl space miner - sim...     20
# 4125   immers yourself into 8-bit ambianc of old scho...     20
# 16905  evil alien with their vehicl and robot are eva...     20
# 3906   if your look for bingo game free to play but y...     20
# 8857   welcom to mansion blast help granni and grandp...     20
# 15676  chicken revolut warrior is an action game fill...     20
# 4247   elev your ark surviv evolv game with the dodod...     20
# 2092   test your gut overcom your fear thriller begin...     20
# 1471   micro battl are back on popular requestgath yo...     20
# 6903   a planet of mine is an engag strategi game tha...     20
# 2985   run hunter run monster runner is a veri excit ...     20
# 6930   one part endless hopperon part zombi shooter n...     20
# 9097   jewel maze 2 is a veri classic jewels-match fu...     20
# 8367   high-end immers tablet gameplayplay the best a...     20
# 15564                        push enemi away use graviti     20
# 8961   9 10 if you enjoy dark sci-fi theme and like a...     20
# 16744  the neon warrior fight championship is here ch...     20
# 6661   we are happi to present you the epic adventur ...     20
# 14743  western man is a classic jump and run game it ...     20
# 8466   domin the leagu in mlb tap sport basebal 2019 ...     20
# 4225   do you have what it take to surviv the shark t...     20
# 8303   march 5 2019 updat noticenew map insid cathedr...     20
# 7685   global battl wage today player from over 100 r...     20
# 15788  the world of stickmen ha a zombi epidem - you ...     20
# 7767   luca thi is the best aircraft shoot game that ...     20
# 15675  chicken warrior zombi huntersequel of chicken ...     20
# 4065   best casual match game ever click on ani 2 adj...     20
# 179    play over 100 million time around the globe an...     20
# 520    do you like citi build and a battl game combin...     20
# 13325  angri lion sim citi attack is about chao rampa...     20
# 6611   all game of the jane hoteljan hotel 1 jane hot...     20
# 9333   kick it old school with the latest game in the...     20
# 8442   in a wild and mystic vike word the vale of dra...     20
# 7181   strateg ftl-like real-tim battl involv choos e...     20
# 6749   experi the uniqu puzzl and critically-acclaim ...     20
# 3090   look for retro rpg action game want to enjoy t...     20
# 8369   welcom to dragon castl where you are in charg ...     20
# 8144   you the greatest and most power summon broke i...     20
# 6959   readi set solv are you the smartest smarter th...     20
# 7925   2020 best strategi gamejoin the abyss of empir...     20
# 7913   readi for a true fantasi rpg with a fantast st...     20
# 3021   multiplay game playplay as a shark with other ...     20
# 2574   play game earn razer silver redeem from hundr ...     20
# 9781   - run a marbl into the chain of color ball and...     20
# 2095   stickman race is a surviv stick game not like ...     20
# 384    onc you pop you cant stop pop stone 2 is a leg...     20
# 6699   follow in the footstep of the great captain se...     20
# 9009   prepar your offload and get readi to maul your...     20
# 4673   attent novel and stori loversiread a romant st...     20
# 210    the best onlin crime syndic game -- -- -- -- -...     20
# 14163  fight arcad game for youbr you a classic fun f...     20
# 1463   bold move is a relax inspir quot match 3 word ...     20

# %%
doc_topic_nmf = pd.DataFrame(doc_topic.round(5),
                             index = df_analysis['title'])
doc_topic_nmf
# Out:
#                                                          0        1        2   \
# title
# World War 2: Offline Strategy                       0.00000  0.00000  0.00000
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.00377  0.00000  0.01095
# MSN Sports - Scores & Schedule                      0.01579  0.00678  0.00000
# QRbot: QR & barcode reader                          0.04767  0.00000  0.00253
# QR & Barcode Scanner                                0.03866  0.00000  0.00311
# ...                                                     ...      ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  0.00000  0.00000
# Mp3 Songs Download                                  0.00153  0.00160  0.00000
# PDF Maker                                           0.01593  0.00000  0.30602
# DSLR Blur Photo                                     0.02296  0.00000  0.10405
# Tarot Card Reading                                  0.15490  0.00000  0.00000
#
#                                                          3        4        5   \
# title
# World War 2: Offline Strategy                       0.04071  0.00000  0.00000
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.00000  0.00000  0.00000
# MSN Sports - Scores & Schedule                      0.00000  0.04138  0.00000
# QRbot: QR & barcode reader                          0.00000  0.00000  0.00000
# QR & Barcode Scanner                                0.00000  0.00000  0.00258
# ...                                                     ...      ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  0.00212  0.00026
# Mp3 Songs Download                                  0.00000  0.00000  0.00220
# PDF Maker                                           0.00000  0.02724  0.00000
# DSLR Blur Photo                                     0.00035  0.00000  0.00000
# Tarot Card Reading                                  0.00108  0.00000  0.01385
#
#                                                          6        7        8   \
# title
# World War 2: Offline Strategy                       0.00000  0.00000  0.03474
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.09151  0.00000  0.00000
# MSN Sports - Scores & Schedule                      0.00047  0.00000  0.00066
# QRbot: QR & barcode reader                          0.01372  0.01026  0.00000
# QR & Barcode Scanner                                0.05150  0.00000  0.00054
# ...                                                     ...      ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  0.00000  0.00000
# Mp3 Songs Download                                  0.00000  0.00066  0.00000
# PDF Maker                                           0.00000  0.00000  0.00059
# DSLR Blur Photo                                     0.00000  0.00000  0.00000
# Tarot Card Reading                                  0.00000  0.00000  0.00000
#
#                                                          9   ...       20  \
# title                                                        ...
# World War 2: Offline Strategy                       0.00000  ...  0.11817
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.00000  ...  0.00000
# MSN Sports - Scores & Schedule                      0.00346  ...  0.07839
# QRbot: QR & barcode reader                          0.00000  ...  0.00000
# QR & Barcode Scanner                                0.00153  ...  0.02051
# ...                                                     ...  ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  ...  0.00000
# Mp3 Songs Download                                  0.03992  ...  0.00000
# PDF Maker                                           0.00000  ...  0.00000
# DSLR Blur Photo                                     0.00000  ...  0.00000
# Tarot Card Reading                                  0.00000  ...  0.00000
#
#                                                          21       22       23  \
# title
# World War 2: Offline Strategy                       0.00067  0.02801  0.00000
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.00000  0.00000  0.04383
# MSN Sports - Scores & Schedule                      0.00329  0.01704  0.02704
# QRbot: QR & barcode reader                          0.00000  0.29019  0.01342
# QR & Barcode Scanner                                0.01498  0.05639  0.01222
# ...                                                     ...      ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  0.00000  0.00740
# Mp3 Songs Download                                  0.00000  0.04694  0.15258
# PDF Maker                                           0.00000  0.00000  0.04384
# DSLR Blur Photo                                     0.00000  0.00000  0.04944
# Tarot Card Reading                                  0.00000  0.00000  0.00000
#
#                                                          24       25       26  \
# title
# World War 2: Offline Strategy                       0.00010  0.03944  0.00000
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.00000  0.23065  0.06018
# MSN Sports - Scores & Schedule                      0.00000  0.00000  0.00721
# QRbot: QR & barcode reader                          0.00000  0.00000  0.00000
# QR & Barcode Scanner                                0.00156  0.00083  0.01209
# ...                                                     ...      ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  0.00000  0.00000
# Mp3 Songs Download                                  0.05232  0.12104  0.00000
# PDF Maker                                           0.05278  0.10124  0.00191
# DSLR Blur Photo                                     0.00000  0.04573  0.00134
# Tarot Card Reading                                  0.00000  0.26151  0.18153
#
#                                                          27       28       29
# title
# World War 2: Offline Strategy                       0.00000  0.00000  0.00099
# All PDF - PDF Reader, PDF Viewer & PDF Converter    0.00000  0.00000  0.00000
# MSN Sports - Scores & Schedule                      0.02443  0.00133  0.02104
# QRbot: QR & barcode reader                          0.00000  0.00000  0.00000
# QR & Barcode Scanner                                0.00018  0.00296  0.00000
# ...                                                     ...      ...      ...
# Aksara Jawa - Nulis Aksara Jawa | Ketik & Konversi  0.00000  0.00000  0.02653
# Mp3 Songs Download                                  0.06906  0.00000  0.04732
# PDF Maker                                           0.00000  0.01374  0.00000
# DSLR Blur Photo                                     0.00000  0.00000  0.00000
# Tarot Card Reading                                  0.03195  0.00000  0.03991
#
# [17141 rows x 30 columns]

# %%
'Mp3 Songs Download' in df_analysis['title']
# Out:
# False

# %% [markdown]
# ### First recommender

# %%
def recommend_app(search):
    app = [search]
    tt = nmf_model.transform(vectorizer.transform(app))
    rec_array = pairwise_distances(tt,doc_topic,metric='cosine').argsort()
    recs = rec_array[0]
    name = df_analysis.loc[recs]
    
    return name[0:5]

# %%
recommend_app('airline flights')
# Out:
#                                                  title  \
# 12053                               Hotels and Flights
# 13762  FabHotels: Safe Rooms on Best Hotel Booking App
# 6023                                     Choice Hotels
# 298            Almosafer: Hotels, Flights and Holidays
# 15522      Treebo: Hotel Booking App | Book Safe Stays
#
#                                                  stemmed  topic
# 12053  find the best deal from 800 airlin and 1200000...     18
# 13762  download fabhotel onlin hotel book app book an...      6
# 6023   travel connect with the choic hotel app everyt...      0
# 298    whether your plan a famili holiday busi trip g...      0
# 15522  treebo hotel book safe stay with the best hote...      6

# %%
recommend_app('play card games')
# Out:
#                                                  title  \
# 7443                      TriPeaks Solitaire Challenge
# 17085  WEWIN (Weme, beme) Vietnam's national card game
# 10421               mobile-pocket loyalty cards wallet
# 7299                                          FreeCell
# 10419                            Cards - Mobile Wallet
#
#                                                  stemmed  topic
# 7443   play the popular solitair game tripeak for fre...      0
# 17085  vietnames card game all vietnames tradit card ...      0
# 10421  mobile-pocket wallet is the easiest way to put...      0
# 7299   freecel is a classic and popular card gamego o...      0
# 10419  some of our user may experi connect issu we ar...      0

# %%
recommend_app('learn to speak hindi')
# Out:
#                                                  title  \
# 14864                         My Korean Teacher : Quiz
# 7603   Learn reading, speaking English for Kids - BiBo
# 7599                  Studycat: Learn English for Kids
# 4893                  German Language Learning - Busuu
# 4899                         Parla: Learn Spanish Free
#
#                                                  stemmed  topic
# 14864  my korean teacher is a game to learn korean th...     29
# 7603   bibo speak english is an educ applic design fr...     29
# 7599   learn english is fun with studycatour educ lan...     29
# 4893   were busuu were an app that make learn a langu...     29
# 4899   parla x is an app for learn languag fast join ...     29

# %%
recommend_app('algebra lessons')
# Out:
#                                                 title  \
# 6915         Baby tracker - feeding, sleep and diaper
# 13333         MentalUP - Learning Games & Brain Games
# 15925                       Baby Hazel Tomato Farming
# 7244   Math Master Educational Game and Brain Workout
# 4569                                        Brilliant
#
#                                                  stemmed  topic
# 6915   babi tracker- breastfeed and babi feed tracker...     14
# 13333  kid want to play mentalup educ learn game brin...     14
# 15925  kid can play babi hazel tomato farm game for f...     14
# 7244   welcom to the offici math mentor app from pari...     14
# 4569   featur in the atlant the new york time npr and...     14

# %%
recommend_app('convert pdf quickly')
# Out:
#                                                    title  \
# 13879  Doc to PDF Converter (xls ppt word png jpg csv...
# 10370                             Explorer+ File Manager
# 13372                                    PDF File Reader
# 11982                                      File Explorer
# 10652  WPS PDF -  Free For PDF Scan, Read, Edit, Convert
#
#                                                  stemmed  topic
# 13879  ani one can easili convert hisher document fil...     17
# 10370  explor a practic no-nonsens file manager- brow...     17
# 13372  docdocx viewer integratedbest pdf reader for 2...     17
# 11982  a simpl file explor with basic function for th...     17
# 10652  featur of wp pdf readerif you love read pdf an...     17

# %%
recommend_app('first person shooter')
# Out:
#                                                title  \
# 11027                    Train shooting - Zombie War
# 5384                                 Raccoon Bubbles
# 14305  Call of Modern World War Hero Sniper Assassin
# 2813                     Gun Master 3: Zombie Slayer
# 9101                               Pocket Basketball
#
#                                                  stemmed  topic
# 11027  train shoot - zombi war come with a highli add...      8
# 5384   shoot bubbl ha never been more relax and funhe...      8
# 14305  here you will becom the best sniper of the wor...      8
# 2813   hone your shoot skill in the militari grade ar...      8
# 9101   pocket basketbal is a simpl yet challeng baske...      8

# %%
recommend_app('pet dog')
# Out:
#                                                    title  \
# 15531              Kids Policeman games: Hippo Detective
# 11385                     Police Dog Attack Prison Break
# 14532         Police Dog Airport Crime Chase : Dog Games
# 4976   Flying Horse Police Chase : US Police Horse Games
# 15050                                   Police Scanner X
#
#                                                  stemmed  topic
# 15531  a crimin world is in action again it mean that...     19
# 11385  rivalri between prison and polic game take a n...     19
# 14532  the secur of the airport is in your hand now t...     19
# 4976   fli polic hors chase crimin with fli hors ride...     19
# 15050  with polic scanner x you can listen to policef...     19

# %%
recommend_app('meet other singles')
# Out:
#                                                    title  \
# 13295                             Online Girls Chat Meet
# 1745                           Hello - Talk, Chat & Meet
# 16666                     Stranger chat: meet new people
# 2431   Mashi - Free Voice Chat Rooms , Party in the Room
# 799              PAGO - Qwikmatch Live chat for Among Us
#
#                                                  stemmed  topic
# 13295  top featur of onlin girl free download app fre...     15
# 1745   alreadi 500000000 call and 250000000 match and...     15
# 16666  fed up with your current random chat unknown c...     15
# 2431   mashi the no1 local free voic chat room app in...     15
# 799    be socialpago is the newest version of qwikmat...     15

# %%
recommend_app('space simulator')
# Out:
#                                   title  \
# 371    MapleStory M - Open World MMORPG
# 8235                      HEIR OF LIGHT
# 6503        CastleStorm - Free to Siege
# 16831          Illuminati vs. Memes MLG
# 2786              Fantasy War Tactics R
#
#                                                  stemmed  topic
# 371    maplestori m the highli anticip follow-up to m...     20
# 8235   a dark fantasi collect rpgdark ha overtaken th...     20
# 6503   welcom to the world of castlestorm - free to s...     20
# 16831  get readi 2 gr8 illuminati battl against memes...     20
# 2786   what newpatch note new expedi area geumhwa pal...     20

# %%
recommend_app('mobile banking')
# Out:
#                                     title  \
# 5278                        POSB digibank
# 5280                      DBS digibank SG
# 5803        LogDog - Mobile Security 2021
# 1126  PassKeep - offline password manager
# 1571         Standard Bank / Stanbic Bank
#
#                                                 stemmed  topic
# 5278  everyday bank made simple-peek at account bala...      0
# 5280  everyday bank made simple-peek at account bala...      0
# 5803  trust by million featur on pc magazin techcrun...      0
# 1126  passkeep is the easiest and the most secur way...     22
# 1571  the standard bank app give you full visibl of ...      0

# %%
recommend_app('war strategy')
# Out:
#                                                   title  \
# 7080        Cat Shooting War: Offline Gunner TD Battles
# 12143            Tank Attack Blitz: Panzer War Machines
# 130       Cyber Dead: Metal Zombie Shooting Super Squad
# 4042            Call of Craft: Blocky Tanks Battlefield
# 5138   Dead Invaders: FPS Shooting Game & Modern War 3D
#
#                                                  stemmed  topic
# 7080   protect your own felin kingdom from evil fight...     20
# 12143  welcom to tank attack blitz panzer war game th...     20
# 130    the dead aris and mix with cyber you mean unde...     20
# 4042   welcom to the world of the tank and awesom gun...     20
# 5138   becom last line of defens and save mankind fro...     20

# %%
recommend_app('make new friends')
# Out:
#                                           title  \
# 3383                Haya - Group Voice Chat App
# 482                                 Yokai Tamer
# 3946                        Hello Kitty Friends
# 2432  Sango -  Free Live Group Voice Chat Rooms
# 8301                               Gaia Odyssey
#
#                                                 stemmed  topic
# 3383  haya fun voic social chat togeth gather friend...     26
# 482   yokai tamer is a super popular japanes style m...     20
# 3946  match 2 blast puzzl game from superawesom lead...     26
# 2432  sango is an interact live group voic chat and ...     20
# 8301  gaia odyssey is a 3d action rpg that give you ...     20

# %%
recommend_app('hindi translation')
# Out:
#                                                  title  \
# 4686                                dict.cc dictionary
# 12360                       English - Hindi Translator
# 326    Portuguese English Dictionary & Translator Free
# 9516      Turkish English Dictionary & Translator Free
# 4992      Spanish English Dictionary & Translator Free
#
#                                                  stemmed  topic
# 4686   dictionari for 51 languag combin usabl without...     29
# 12360  learn hindi or visit a hindi speak countri eas...     29
# 326    easili learn portugues with portugues english ...     29
# 9516   easili learn turkish english with turkish engl...     29
# 4992   easili learn spanish english with spanish engl...     29

# %%
recommend_app('listen to music')
# Out:
#                                title  \
# 14245       Music Player For Samsung
# 2320   Lowriders Comeback 2 : Russia
# 16172   Equalizer Pro & Bass Booster
# 13338      Free Music for SoundCloud
# 3535     PowerAudio Pro Music Player
#
#                                                  stemmed  topic
# 14245  music player for samsung galaxi - s11 music pl...     13
# 2320   the biggest music game about lowridersfeatures...     13
# 16172  equal pro bass booster with easy-to-us home wi...     13
# 13338  million of trendinghottop music all free downl...     13
# 3535   poweraudio music player is the mostpow music p...     13

# %%
recommend_app('piano lessons')
# Out:
#                                                  title  \
# 12050           Music Kids - Songs & Music Instruments
# 7204                      Lullabies Relax & Sleep Baby
# 7102                                Music box to sleep
# 7103                           Sound to children sleep
# 7955   Baby Zoo Piano with Music for Toddlers and Kids
#
#                                                  stemmed  topic
# 12050  music kid is a great fun music box creat espec...     13
# 7204   want your babi to fall asleep quickli just cho...     13
# 7102   your babi can not sleep cri a lot whi do not y...     13
# 7103   a beauti sound to the parent put their babi to...     13
# 7955   babi zoo piano is an excel entertain and educ ...     14

# %%
recommend_app('secure vpn app')
# Out:
#                                                    title  \
# 11348            Free WiFi Internet - Data Usage Monitor
# 10828           WiFi Router Scanner - Who is on my WiFi?
# 11911  Chart signals & Network speed test 3g 4g 5g Wi-Fi
# 5766        WiFi Speed Test - WiFi Signal Strength Meter
# 2116   Who is on my WiFi - Network Scanner & WiFi Sca...
#
#                                                  stemmed  topic
# 11348  app offer updat premium featur for free who us...     22
# 10828  wifi router scanner - who is on my wifi is pow...     22
# 11911  chart signal network speed test 3g 4g 5g wi-fi...     22
# 5766   wifi speed test - wifi signal strength meter i...     22
# 2116   who is on my wifi - network scanner wifi scann...     22

# %%
df_short = df[['title','description','summary','score','free','genre','icon','year','contentRating']].copy()

# %%
df_merged = pd.merge(
                    df_short,
                    doc_topic_nmf,
                    how="inner",
                    on='title',
                    left_index=False,
                    right_index=False,
                    sort=True,
                    suffixes=("_x", "_y"),
                    copy=True,
                    indicator=False,
                    validate=None,
)

# %%
with open('df_apps_topics.pkl', 'wb') as f:
    pickle.dump(df_merged, f)

# %%
with open('nmf_model.pkl', 'wb') as f:
    pickle.dump(nmf_model, f)

# %%
with open('vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

# %%
with open('doc_topic_array.pkl', 'wb') as f:
    pickle.dump(doc_topic, f)

# %%
#Alarm Adzan Otomatis Muslim Indonesia 2020 : T...
#Aksara Jawa - Nulis Aksara Jawa | Ketik & Konv...
#Lotto Results - Mega Millions Powerball Lotter...
