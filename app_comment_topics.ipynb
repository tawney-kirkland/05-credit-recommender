# %%
import pandas as pd
from pandas import option_context
import numpy as np
import re
import string

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import MWETokenizer
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer, PorterStemmer

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 

from collections import Counter

from textblob import TextBlob

# %%
df = pd.read_csv('04-data/preprocessed_app_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22015 entries, 0 to 22014
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     22015 non-null  object
#  1   description               22015 non-null  object
#  2   summary                   22014 non-null  object
#  3   installs                  22015 non-null  object
#  4   minInstalls               22015 non-null  float64
#  5   score                     22015 non-null  float64
#  6   ratings                   22015 non-null  float64
#  7   reviews                   22015 non-null  float64
#  8   histogram                 22015 non-null  object
#  9   price                     22015 non-null  float64
#  10  free                      22015 non-null  int64
#  11  currency                  22015 non-null  object
#  12  sale                      22015 non-null  bool
#  13  offersIAP                 22015 non-null  bool
#  14  inAppProductPrice         10301 non-null  object
#  15  size                      22015 non-null  object
#  16  androidVersion            21988 non-null  object
#  17  androidVersionText        21988 non-null  object
#  18  developer                 22015 non-null  object
#  19  developerId               22015 non-null  object
#  20  privacyPolicy             21211 non-null  object
#  21  developerInternalID       22015 non-null  float64
#  22  genre                     22015 non-null  object
#  23  genreId                   22015 non-null  object
#  24  icon                      22015 non-null  object
#  25  headerImage               22012 non-null  object
#  26  screenshots               22015 non-null  object
#  27  video                     7342 non-null   object
#  28  videoImage                7342 non-null   object
#  29  contentRating             22015 non-null  object
#  30  contentRatingDescription  4784 non-null   object
#  31  adSupported               17861 non-null  object
#  32  containsAds               22015 non-null  int64
#  33  released                  22015 non-null  object
#  34  updated                   22015 non-null  object
#  35  version                   22012 non-null  object
#  36  recentChanges             17616 non-null  object
#  37  comments                  22015 non-null  object
#  38  editorsChoice             22015 non-null  int64
#  39  appId                     22015 non-null  object
#  40  url                       22015 non-null  object
#  41  year                      22015 non-null  int64
#  42  updated_year              22015 non-null  int64
#  43  description_clean         22012 non-null  object
#  44  hist_clean                22015 non-null  object
#  45  star_1                    22015 non-null  int64
#  46  star_2                    22015 non-null  int64
#  47  star_3                    22015 non-null  int64
#  48  star_4                    22015 non-null  int64
#  49  star_5                    22015 non-null  int64
#  50  top_developer             22015 non-null  int64
#  51  current_date              22015 non-null  object
#  52  days                      22015 non-null  int64
#  53  installs_day              22015 non-null  float64
#  54  updated_days              22015 non-null  int64
#  55  has_video                 22015 non-null  int64
# dtypes: bool(2), float64(7), int64(14), object(33)
# memory usage: 9.1+ MB

# %%
df.title.nunique()
# Out:
# 22015

# %%
df[df['title'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [title, description, summary, installs, minInstalls, score, ratings, reviews, histogram, price, free, currency, sale, offersIAP, inAppProductPrice, size, androidVersion, androidVersionText, developer, developerId, privacyPolicy, developerInternalID, genre, genreId, icon, headerImage, screenshots, video, videoImage, contentRating, contentRatingDescription, adSupported, containsAds, released, updated, version, recentChanges, comments, editorsChoice, appId, url, year, updated_year, description_clean, hist_clean, star_1, star_2, star_3, star_4, star_5, top_developer, current_date, days, installs_day, updated_days, has_video]
# Index: []
#
# [0 rows x 56 columns]

# %%
df_analysis = df[['title','score','comments']].copy()
df_analysis.reset_index(drop=True,inplace=True)

# %%
df_analysis = pd.DataFrame(df_analysis.comments.str.split(",").tolist(), index=df_analysis.title).stack()
df_analysis = df_analysis.reset_index([0, 'title'])
df_analysis.columns = ['title', 'comments']

# %%
df_analysis
# Out:
#                                  title  \
# 0        World War 2: Offline Strategy
# 1        World War 2: Offline Strategy
# 2        World War 2: Offline Strategy
# 3        World War 2: Offline Strategy
# 4        World War 2: Offline Strategy
# ...                                ...
# 1473040             Tarot Card Reading
# 1473041             Tarot Card Reading
# 1473042             Tarot Card Reading
# 1473043             Tarot Card Reading
# 1473044             Tarot Card Reading
#
#                                                   comments
# 0                                 ["I just started playing
# 1         I'm on the 3rd level and it's already so hard...
# 2         games are fun when they are easy to play but ...
# 3         plus there are way too many ads on this game....
# 4                   "Fun game to play with decent graphics
# ...                                                    ...
# 1473040
# 1473041                    we all are destined to be here
# 1473042   there and maybe for the unsure anywhere for a...
# 1473043   'This app is very awesome and amazing and eve...
# 1473044   'Not enough content to motivate me to deal wi...
#
# [1473045 rows x 2 columns]

# %%
def clean_text(text):
    '''Make text lowercase, remove punctuation, remove links and mentions'''
    text = text.lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub('[0-9\n]',' ',text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub("\s\s+", " ", text)
    
    return text

df_analysis['comments'] = df_analysis.comments.map(clean_text)

# %%
df['tokens'] = df.comments.apply(nltk.word_tokenize)

# %%
stemmer = PorterStemmer()

df['stemmed'] = df['tokens'].apply(lambda x: [stemmer.stem(y) for y in x])

# %%
df.tokens = df.tokens.apply(lambda x: ' '.join(x))

# %%
df.stemmed = df.stemmed.apply(lambda x: ' '.join(x))

# %%
df_analysis = df[['title','stemmed']].copy()
df_analysis.reset_index(drop=True,inplace=True)

# %%
df_analysis
# Out:
#                                                    title  \
# 0                          World War 2: Offline Strategy
# 1      SoundSeeder -Play music simultaneously and in ...
# 2       All PDF - PDF Reader, PDF Viewer & PDF Converter
# 3                         MSN Sports - Scores & Schedule
# 4                             QRbot: QR & barcode reader
# ...                                                  ...
# 22010                                          Gas Pedal
# 22011                                          PDF Maker
# 22012                                    DSLR Blur Photo
# 22013                     Shoppers Stop Fashion Shopping
# 22014                                 Tarot Card Reading
#
#                                                  stemmed
# 0      [ `` I just start play , I 'm on the 3rd level...
# 1      [ `` onli need to buy the app on the devic you...
# 2      [ 'fine , with mani featur . but somewhat fail...
# 3      [ `` I had been experienc the same lost favori...
# 4      [ `` the ad free version of thi app is the bes...
# ...                                                  ...
# 22010  [ 'when I start the car it goe sicko mode and ...
# 22011  [ 'it work . but rotat by itself the imag , ev...
# 22012  [ `` thi app is great and I can blur my pic to...
# 22013  [ 'atroci app ... I place an order in the mont...
# 22014  [ 'doe not open and stay in an Ad page right f...
#
# [22015 rows x 2 columns]

# %%
stop = stopwords.words('english')
stop.extend(['free','new','get','hd','use','game','games','make','makes','play',
             'fun','features', 'need','live', 'also','using','best','us','app','apps', 'one', '2020','2021',
            'this','like','enjoy','thing','free'])

# # Extend for most common English adverbs

stop.extend(['up','so','out','just','now','how','then','more','also','here',
            'well','only','very','even','back','there','down','still','in',
            'as','to','when','never','really','most','on','why','about','over',
            'again','where','right','off','always','today','all','far','long',
            'away','yet','often','ever','however','almost','later','much',
            'once','least','ago','together','around','already','enough','both',
            'maybe','actually','probably','home','of course','perhaps','little',
            'else','sometimes','finally','less','better','early','especially',
            'either','quite','simply','nearly','soon','certainly','quickly',
            'no','recently','before','usually','thus','exactly','hard',
            'particularly','forward','ok','okay','clearly','indeed',
            'rather','that','tonight','close','suddenly','best','instead',
            'ahead','fast','alone','eventually','directly'])


stop.extend(['car','race','go','thi','thing','becaus','thank','give','people',
            'interest','pleas','thing','every','way','player','win',
            'onli','coin','spend','say','want','realli','veri','wa',
            'because','very','many','puzzle','onli','challeng','great',
            'nice','cute','good','would','easi','peopl','time','tri',
            'take','buy','mani','everi','pop','doe','set','amaz','easi',
            'ha','robot','drive','video','download','record','song','music',
            'level','ca','photo','wonder','star','show','think','awesom',
            'could','got','shoot','lot','easili','love','cool','tv','fantast',
            '30','truck','ani','first','add','bad','editor','beauti','recommend',
            'day'])

# ## Extend for prepositions
stop.extend(['without','among'])

# %%
vectorizer = CountVectorizer(stop_words = stop)

doc_word = vectorizer.fit_transform(df_analysis.stemmed)
# Out:
# /Users/tawneykirkland/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['course'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
nmf_model = NMF(10)
doc_topic = nmf_model.fit_transform(doc_word)
topic_word = nmf_model.components_

# %%
words = vectorizer.get_feature_names()
t = nmf_model.components_.argsort(axis=1)[:,-1:-10:-1]
topic_words = [[words[e] for e in l] for l in t]
topic_words
# Out:
# [['work',
#   'phone',
#   'connect',
#   'devic',
#   'android',
#   'instal',
#   'screen',
#   'camera',
#   'turn'],
#  ['ad',
#   'watch',
#   'second',
#   'uninstal',
#   'annoy',
#   'advertis',
#   'remov',
#   'start',
#   'minut'],
#  ['money',
#   'pay',
#   'start',
#   'keep',
#   'watch',
#   'charact',
#   'point',
#   'fix',
#   'upgrad'],
#  ['graphic',
#   'control',
#   'featur',
#   'simul',
#   'gameplay',
#   'real',
#   'sound',
#   'mission',
#   'develop'],
#  ['applic',
#   'featur',
#   'work',
#   'help',
#   'instal',
#   'edit',
#   'store',
#   'mobil',
#   'develop'],
#  ['learn',
#   'help',
#   'word',
#   'english',
#   'languag',
#   'translat',
#   'know',
#   'understand',
#   'find'],
#  ['updat',
#   'fix',
#   'open',
#   'problem',
#   'version',
#   'issu',
#   'crash',
#   'load',
#   'keep'],
#  ['wallpap',
#   'color',
#   'pictur',
#   'look',
#   'screen',
#   'option',
#   'phone',
#   'chang',
#   'see'],
#  ['read',
#   'book',
#   'stori',
#   'chapter',
#   'charact',
#   'page',
#   'news',
#   'ticket',
#   'find'],
#  ['order',
#   'servic',
#   'call',
#   'custom',
#   'account',
#   'card',
#   'number',
#   'email',
#   'deliveri']]

# %%
df_analysis['topic'] = doc_topic.argmax(axis=1)

# %%
df_analysis[df_analysis['topic'] ==7].sample(60)
# Out:
#                                                    title  \
# 13090                               Bokeh Camera Effects
# 1039                               Anime Kawaii Dress Up
# 48                             Neon Tiger Keyboard Theme
# 21012                          Super Fashion Designer HD
# 16365                                   Kids Doodle Glow
# 12554                             Remove & Add Watermark
# 12744                    Wallpapers for Chat Backgrounds
# 6486   Picta Photo Print - Free Same Day Photo Prints...
# 15820                 Happy new year 2021 live wallpaper
# 5427                          Glitter Ice Cream Coloring
# 11648                                   SLT Ubuntu Style
# 20085                                          Cute memo
# 11636                     Calendar+ Schedule Planner App
# 816        Banner Maker, Thumbnail Maker, Web Banner Ads
# 15542                       Simple Analog Clock [Widget]
# 3760      Magic Coloring: Coloring pages Color by number
# 7343               Grid Maker for Instagram - PhotoSplit
# 16166    Unicorn Ice Cream Maker - Frozen Sweet Desserts
# 4195                                      Cool Ringtones
# 8295                         Find Differences 200 levels
# 20152                           Live Wallpaper of Matrix
# 11401       Girlish Kitty Wallpapers Keyboard Background
# 8298                      Find the Difference 200 levels
# 1779             Fire Wallpaper and Keyboard - Lone Wolf
# 12504                          Love Photo frames Collage
# 19471                             Lion GO Launcher Theme
# 5202        Keyboard - My Photo keyboard, Emoji Keyboard
# 7806                                      Star Link Free
# 11180                      Colorful Magic Live Wallpaper
# 588                                          WhatTheFont
# 12018                       FitMenCook - Healthy Recipes
# 12438                                Photo Color Changer
# 17684                                  Screen Flashlight
# 7211                           Text on Photo - Fontmania
# 5500      DopeWalls- 4K Wallpapers & HD Background (UHD)
# 2179                                Mermaid Photo Editor
# 17833                             Urbex People Wallpaper
# 9217                                         Magic Poser
# 2803                    Dj Music Cool Man Keyboard Theme
# 13835  Text on pictures - Write words & text art on p...
# 20239              Battle Royale Season 11 HD Wallpapers
# 11440                   Green Diamond Bow Keyboard Theme
# 14224                            AppLock Theme Butterfly
# 14236                     Custom Font Installer For MIUI
# 15596                    Blix Gazetka Gazetki Promocyjne
# 5917                              Backdrops - Wallpapers
# 11445                 Galaxy Rainbow Keyboard Background
# 11438                     Neon Heart Love Keyboard Theme
# 11448                         Simple Grey Keyboard Theme
# 7717                           Audio Recorder and Editor
# 16487         Cake with Name wishes - Write Name On Cake
# 13086                                      Zombie Camera
# 18576                               BeatBox Music Player
# 2802                        Sneaker Just Sports Keyboard
# 7193      Thumbnail Maker - Create Banners & Channel Art
# 8199                                      TF: Light Bulb
# 11188                               Launcher For Samsung
# 11544                                              Notas
# 12755                                     Sad Wallpapers
# 17857     FoxEyes - Change Eye Color by Real Anime Style
#
#                                                  stemmed  topic
# 13090  [ 'nice effect but most are unus as a full pho...      7
# 1039   [ 'so fun ! there is a litrl bug though ... I ...      7
# 48     [ 'nice what a app ! ! fast and easi to use tr...      7
# 21012  [ `` thi game look like a great game until you...      7
# 16365  [ `` game wa good my child love it and i found...      7
# 12554  [ `` i'wil write a honest one , thi app ca n't...      7
# 12744  [ `` I am give thi app 4 star becaus when I wa...      7
# 6486   [ ' I enjoy it . easi to use , but I am not su...      7
# 15820  [ `` thi a realli veri nice app ..... but i do...      7
# 5427   [ `` It is veri relax when you just need somet...      7
# 11648  [ `` I 've instal sever type of launcher , and...      7
# 20085  [ `` I use thi for 1 year more . mani import t...      7
# 11636  [ 'easi to use , love the color code but there...      7
# 816    [ `` So help and amaz . It did everyth I want ...      7
# 15542  [ `` I wa use nativ android analog clock widge...      7
# 3760   [ `` I 've been use thi color app for 3-4 year...      7
# 7343   [ ' I realli love thi app , it so easi to use ...      7
# 16166  [ ' 5 star for 3 ice cream choic ... I realli ...      7
# 4195   [ `` Ok i like cool rington caus it 's someth ...      7
# 8295   [ `` sort of fun to do , but it ha some idiosy...      7
# 20152  [ 'im disappoint . everyon . you can still acc...      7
# 11401  [ `` I so cute & gorgou to use is simpl and mo...      7
# 8298   [ `` I like the game but there are way to mani...      7
# 1779   [ 'to be honest , I thought it would be rubbis...      7
# 12504  [ `` nice app it 's better to keep some more f...      7
# 19471  [ ' I just melt after see such beauti , i woul...      7
# 5202   [ 'thi ha some ad but not that mani . thi need...      7
# 7806   [ 'game is over all veri good for time pass bu...      7
# 11180  [ ' I think thi app is veri good . and l like ...      7
# 588    [ 'overal good app . but the app now give an e...      7
# 12018  [ 'thi app is truli amaz . I use it for year a...      7
# 12438  [ `` realli bad , when I chose the pictur to c...      7
# 17684  [ `` It 's almost perfect ! It would be aweson...      7
# 7211   [ `` I might have bought the app but I 'd need...      7
# 5500   [ `` the app.it wa good . nice wallpap collect...      7
# 2179   [ 'best app ever love all the filter the best ...      7
# 17833  [ 'thi is good and should have more photo ' , ...      7
# 9217   [ `` quit entertain for me , realli . I may be...      7
# 2803   [ ' I total love thi app ! ! ! becaus i total ...      7
# 13835  [ `` use for 2 yr now crash . open it , and it...      7
# 20239  [ 'um ... thi app take such a long time to sho...      7
# 11440  [ 'thi is to `` chaitu amu on 11/29/20 '' , no...      7
# 14224  [ `` I do n't like thi app it 's onli set up o...      7
# 14236  [ `` the io 13.2 emoji doe n't work on ani ins...      7
# 15596  [ ' A perfect app . befor have it , I had a ha...      7
# 5917   [ `` I ve bought the premium app some day ago ...      7
# 11445  [ ' I love thi app so much ! I give it a 4 sta...      7
# 11438  [ 'can easili read each key , some custom one ...      7
# 11448  [ `` ... it 's a bloodi boobi trap . do n't ev...      7
# 7717   [ 'the best voic record app I have tri . thi a...      7
# 16487  [ 'realli like that you are abl to chang the f...      7
# 13086  [ `` thi app is good but it 'll be great if so...      7
# 18576  [ `` I ca n't edit the tag within the app itse...      7
# 2802   [ ' I alway give 5 star . but i love thi keybo...      7
# 7193   [ `` It 's quit good depend what you want it f...      7
# 8199   [ `` thi is one of the 1st app I download on a...      7
# 11188  [ `` Do n't ever download thi ap becaus if you...      7
# 11544  [ `` after a year you give new updat but witho...      7
# 12755  [ 'thi app is amaz I download it yesterday and...      7
# 17857  [ ' I am look for a coupl of week , and the ot...      7

# %%
# [['call',
#   'account',
#   'servic',
#   'phone',
#   'card',
#   'number',
#   'messag',
#   'custom',
#   'email'],
#  ['ad',
#   'watch',
#   'add',
#   'second',
#   'uninstal',
#   'annoy',
#   'bad',
#   'advertis',
#   'remov'],
#  ['work',
#   'phone',
#   'connect',
#   'devic',
#   'android',
#   'screen',
#   'instal',
#   'camera',
#   'turn'],
#  ['graphic',
#   'control',
#   'bad',
#   'add',
#   'featur',
#   'simul',
#   'real',
#   'gameplay',
#   'fantast'],
#  ['applic',
#   'featur',
#   'recommend',
#   'fantast',
#   'work',
#   'beauti',
#   'help',
#   'instal',
#   'store'],
#  ['learn',
#   'help',
#   'word',
#   'english',
#   'read',
#   'languag',
#   'translat',
#   'know',
#   'find'],
#  ['updat',
#   'fix',
#   'open',
#   'problem',
#   'version',
#   'issu',
#   'crash',
#   'load',
#   'keep'],
#  ['order',
#   'item',
#   'servic',
#   'deliveri',
#   'custom',
#   'product',
#   'food',
#   'shop',
#   'price'],
#  ['money',
#   'pay',
#   'day',
#   'start',
#   'stori',
#   'keep',
#   'first',
#   'charact',
#   'watch'],
#  ['wallpap',
#   'color',
#   'pictur',
#   'add',
#   'look',
#   'option',
#   'screen',
#   'phone',
#   'chang']]
